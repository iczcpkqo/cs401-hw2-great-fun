# %%
import re
import os
import pandas as pd
from gensim import corpora, models
import numpy as np
from nltk.corpus import stopwords
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-8a2ceb52f980> in <module>
#       2 import os
#       3 import pandas as pd
# ----> 4 from gensim import corpora, models
#       5 import numpy as np
#       6 from nltk.corpus import stopwords
#
# ModuleNotFoundError: No module named 'gensim'

# %%
#读取文件，提取字段
file_path="./news-data/"
fileList = os.listdir(file_path)

file_List=[]
SOURCE_List=[]
AGENT_List=[]
GOAL_List=[]
DATA_List=[]
METHODS_List=[]
RESULTS_List=[]
ISSUES_List=[]
SCORE_List=[]
COMMENTS_List=[]

for f in fileList:
    print(file_path+f)
    with open(file_path+f,encoding='iso-8859-1') as file_obj:
        content = file_obj.read()
        file_List.append(f)
        SOURCE ="".join(re.findall('SOURCE(.*?)AGENT', content, re.S)).replace("\n","").replace("==","")
    #     print(SOURCE)
        SOURCE_List.append(SOURCE)
        AGENT = "".join(re.findall('AGENT(.*?)GOAL', content, re.S)).replace("\n","").replace("==","")
#         print(AGENT)
        AGENT_List.append(AGENT)
        GOAL = "".join(re.findall('GOAL(.*?)DATA', content, re.S)).replace("\n","").replace("==","")
#         print(GOAL)
        GOAL_List.append(GOAL)
        DATA = "".join(re.findall('DATA(.*?)METHODS', content, re.S)).replace("\n","").replace("==","")
#         print(DATA)
        DATA_List.append(DATA)
        METHODS = "".join(re.findall('METHODS(.*?)RESULTS', content, re.S)).replace("\n","").replace("==","")
#         print(METHODS)
        METHODS_List.append(METHODS)
        RESULTS = "".join(re.findall('RESULTS(.*?)ISSUES', content, re.S)).replace("\n","").replace("==","")
#         print(RESULTS)
        RESULTS_List.append(RESULTS)
        ISSUES = "".join(re.findall('ISSUES(.*?)SCORE', content, re.S)).replace("\n","").replace("==","")
#         print(ISSUES)
        ISSUES_List.append(ISSUES)
        SCORE = "".join(re.findall('SCORE(.*?)COMMENTS', content, re.S)).replace("\n","").replace("==","")
#         print(SCORE)
        SCORE_List.append(SCORE)
        COMMENTS = "".join(re.findall('COMMENTS(.+)', content, re.S)).replace("\n","").replace("==","")
#         print(COMMENTS)
        COMMENTS_List.append(COMMENTS)
# Out:
# ./news-data/0080846114c8ae51
# ./news-data/00b02003d26e10c9
# ./news-data/00d25ff5a5d90ac9
# ./news-data/011a8060b96d68f5
# ./news-data/01754bb64df52491
# ./news-data/02e661d3a7239aef
# ./news-data/04191d392800b0cd
# ./news-data/04fab8668619dccc
# ./news-data/05e0e07f1f67f2a3
# ./news-data/05f3ef7c2296a9a8
# ./news-data/060fa3e81e1ea185
# ./news-data/0676c18f7633174b
# ./news-data/075b280c300ee7db
# ./news-data/078fd36bf4fdd39f
# ./news-data/07daf23559654621
# ./news-data/084237167fad7c9a
# ./news-data/090525a7bce5e763
# ./news-data/098a8cacbf66e097
# ./news-data/09fdde875b7275b8
# ./news-data/0b03e0ba7503128c
# ./news-data/0d9389da67431421
# ./news-data/0db703a375ced201
# ./news-data/0ef148a015be44cf
# ./news-data/0fc4d8ea8e4b3c80
# ./news-data/10cd2a584f501bef
# ./news-data/1209c6b53c3c2acb
# ./news-data/efef72371406cb93
# ./news-data/f0146ed75f1d35a9
# ./news-data/f075ebf85f7e9299
# ./news-data/f1384bd155f1ad29
# ./news-data/f23d524ecb173ad9
# ./news-data/f2d335794769d8a2
# ./news-data/f353cc3062833c6f
# ./news-data/f3c44c216d6264a3
# ./news-data/f3c4bf00b7aeb3c8
# ./news-data/f456d1f1172dae32
# ./news-data/f4d6b388e5a064a7
# ./news-data/f57e5f60d934d363
# ./news-data/f5e192ed5ce72a40
# ./news-data/f66a56e2c4813121
# ./news-data/f6dafe77ce4e84a0
# ./news-data/f79f0174d4d375eb
# ./news-data/f80628461d0f5baa
# ./news-data/f93fb2d78a2996a9
# ./news-data/f963a20c177f5893
# ./news-data/f972f8e54a6e96c1
# ./news-data/f9b8a5d36032fba5
# ./news-data/faa17c0f1217eb56
# ./news-data/fb975c3aa0f08cee
# ./news-data/fcf271ee3b36865d
# ./news-data/ffea5d4bf37fb8d1

# %%
#构造为df
data=pd.DataFrame({"file":file_List,"SOURCE":SOURCE_List,"AGENT":AGENT_List,"GOAL":GOAL_List,"DATA":DATA_List,"METHODS":METHODS_List,"RESULTS":RESULTS_List,"ISSUES":ISSUES_List,"SCORE":SCORE_List,"COMMENTS":COMMENTS_List})

# %%
data
# Out:
#                  file                                             SOURCE  \
# 0    0080846114c8ae51  https://www.nature.com/articles/d41586-019-033...
# 1    00b02003d26e10c9  https://deepmind.com/blog/neural-scene-represe...
# 2    00d25ff5a5d90ac9  https://news.mit.edu/2020/translating-lost-lan...
# 3    011a8060b96d68f5  https://fortune.com/2020/10/13/waymo-autonomou...
# 4    01754bb64df52491  https://www.wired.co.uk/article/how-do-netflix...
# ..                ...                                                ...
# 377  f9b8a5d36032fba5  https://www.cognizant.com/en-uk/artificial-int...
# 378  faa17c0f1217eb56  https://www.theverge.com/2018/7/26/17619382/ib...
# 379  fb975c3aa0f08cee
# 380  fcf271ee3b36865d  https://www.lemonde.fr/les-cles-de-demain/arti...
# 381  ffea5d4bf37fb8d1  > Netflix Awards $1 Million Prize and Starts a...
#
#                                                  AGENT  \
# 0     Swiss Federal Institute of Technology (ETH) i...
# 1             Machines with computer vision equipment
# 2                                                 MIT
# 3                            Waymo (Google Subsidary)
# 4                                              Netflix
# ..                                                 ...
# 377                                         Cognizant
# 378                 IBMâs âWatson for Oncologyâ
# 379
# 380                                               IBM
# 381  Competition Hosted by **Netflix**Algorithm cre...
#
#                                                   GOAL  \
# 0                     To discover new laws of physics
# 1    Identify objects by name and physical appearance
# 2    A new system that is able to automatically dec...
# 3                                   Autonomous trucks
# 4    Give customers shows that they like but would ...
# ..                                                 ...
# 377  Set a base-line for AI-Augmented future in the...
# 378              diagnose and treat and ill patients.
# 379
# 380  They are trying to create an AI able to analys...
# 381  **Improve by at least 10%** the accuracy of Ne...
#
#                                                   DATA  \
# 0    Observational data of the trajectory of Mars a...
# 1
# 2    Extracted pairs of Linear B scripts(words) and...
# 3    Data was collected by real world experience dr...
# 4    Explicit data given by customers when they lik...
# ..                                                 ...
# 377  To facilitate human-AI augmentation, organizat...
# 378  symptoms and treatments for a range of illness...
# 379
# 380  The data used come from the videos already rec...
# 381  Data in quadruplet form: <user, movie, date of...
#
#                                                METHODS  \
# 0                                                  RL
# 1
# 2    character-based sequence-to-sequence (seq2seq)...
# 3    Waymo try improve upon driving visibility of a...
# 4    Use machine learning algorithms to place custo...
# ..                                                 ...
# 377  They implemened the cognitive task master mode...
# 378  the system contained knowledge and symptoms of...
# 379
# 380                Not mentioned, probably supervised
# 381  BellKor Algorithm contains:- Neighborhood-base...
#
#                                                RESULTS  \
# 0    Positioned the Sun as a center-piece of the so...
# 1
# 2    Achieved a 5.5% absolute improvement when appl...
# 3    Waymo declined to awnser on the performance of...
# 4
# ..                                                 ...
# 377
# 378  the project was scrapped following several ser...
# 379
# 380  For now, the AI is able to recognize a person ...
# 381  What were their results?BellKor's Pragmatic Ch...
#
#                                                 ISSUES SCORE  \
# 0    Human involvement is still needed to interpret...    8
# 1
# 2                                                         7
# 3    Self driving vehicles or semi-self driving veh...    8
# 4
# ..                                                 ...   ...
# 377                                                       9
# 378  The AI based its calulations and predictions o...    1
# 379
# 380  The biggest technical issue is the lack of pro...    4
# 381  Evident privacy concerns regarding that datase...    7
#
#                                               COMMENTS
# 0    Interesting to know that not only laws of phys...
# 1    This article discusses computer vision and mac...
# 2    This field is still being actively researched ...
# 3    The fact that Waymo refused to comment on the ...
# 4    This media article focuses more on the outcome...
# ..                                                 ...
# 377  This report is a useful case study on human in...
# 378  for what seemed like a hopeful and life saving...
# 379
# 380  The article gives not a lot of technical infor...
# 381  The press generally did not explain their algo...
#
# [382 rows x 10 columns]

# %%
list_stopWords=list(set(stopwords.words('english')))

# %%
#对要聚类的字段做清洗，大写转小写，只保留单词，去除多个空格
data["GOAL_clean"]=data.apply(lambda x:re.sub('\s+', ' ',re.sub('[^a-z ]+', ' ',x["GOAL"].lower())),axis=1)
data["DATA_clean"]=data.apply(lambda x:re.sub('\s+', ' ',re.sub('[^a-z ]+', ' ',x["DATA"].lower())),axis=1)
data["METHODS_clean"]=data.apply(lambda x:re.sub('\s+', ' ',re.sub('[^a-z ]+', ' ',x["METHODS"].lower())),axis=1)
data["RESULTS_clean"]=data.apply(lambda x:re.sub('\s+', ' ',re.sub('[^a-z ]+', ' ',x["RESULTS"].lower())),axis=1)
data["ISSUES_clean"]=data.apply(lambda x:re.sub('\s+', ' ',re.sub('[^a-z ]+', ' ',x["ISSUES"].lower())),axis=1)
data["COMMENTS_clean"]=data.apply(lambda x:re.sub('\s+', ' ',re.sub('[^a-z ]+', ' ',x["COMMENTS"].lower())),axis=1)

# %%
data
# Out:
#                  file                                             SOURCE  \
# 0    0080846114c8ae51  https://www.nature.com/articles/d41586-019-033...
# 1    00b02003d26e10c9  https://deepmind.com/blog/neural-scene-represe...
# 2    00d25ff5a5d90ac9  https://news.mit.edu/2020/translating-lost-lan...
# 3    011a8060b96d68f5  https://fortune.com/2020/10/13/waymo-autonomou...
# 4    01754bb64df52491  https://www.wired.co.uk/article/how-do-netflix...
# ..                ...                                                ...
# 377  f9b8a5d36032fba5  https://www.cognizant.com/en-uk/artificial-int...
# 378  faa17c0f1217eb56  https://www.theverge.com/2018/7/26/17619382/ib...
# 379  fb975c3aa0f08cee
# 380  fcf271ee3b36865d  https://www.lemonde.fr/les-cles-de-demain/arti...
# 381  ffea5d4bf37fb8d1  > Netflix Awards $1 Million Prize and Starts a...
#
#                                                  AGENT  \
# 0     Swiss Federal Institute of Technology (ETH) i...
# 1             Machines with computer vision equipment
# 2                                                 MIT
# 3                            Waymo (Google Subsidary)
# 4                                              Netflix
# ..                                                 ...
# 377                                         Cognizant
# 378                 IBMâs âWatson for Oncologyâ
# 379
# 380                                               IBM
# 381  Competition Hosted by **Netflix**Algorithm cre...
#
#                                                   GOAL  \
# 0                     To discover new laws of physics
# 1    Identify objects by name and physical appearance
# 2    A new system that is able to automatically dec...
# 3                                   Autonomous trucks
# 4    Give customers shows that they like but would ...
# ..                                                 ...
# 377  Set a base-line for AI-Augmented future in the...
# 378              diagnose and treat and ill patients.
# 379
# 380  They are trying to create an AI able to analys...
# 381  **Improve by at least 10%** the accuracy of Ne...
#
#                                                   DATA  \
# 0    Observational data of the trajectory of Mars a...
# 1
# 2    Extracted pairs of Linear B scripts(words) and...
# 3    Data was collected by real world experience dr...
# 4    Explicit data given by customers when they lik...
# ..                                                 ...
# 377  To facilitate human-AI augmentation, organizat...
# 378  symptoms and treatments for a range of illness...
# 379
# 380  The data used come from the videos already rec...
# 381  Data in quadruplet form: <user, movie, date of...
#
#                                                METHODS  \
# 0                                                  RL
# 1
# 2    character-based sequence-to-sequence (seq2seq)...
# 3    Waymo try improve upon driving visibility of a...
# 4    Use machine learning algorithms to place custo...
# ..                                                 ...
# 377  They implemened the cognitive task master mode...
# 378  the system contained knowledge and symptoms of...
# 379
# 380                Not mentioned, probably supervised
# 381  BellKor Algorithm contains:- Neighborhood-base...
#
#                                                RESULTS  \
# 0    Positioned the Sun as a center-piece of the so...
# 1
# 2    Achieved a 5.5% absolute improvement when appl...
# 3    Waymo declined to awnser on the performance of...
# 4
# ..                                                 ...
# 377
# 378  the project was scrapped following several ser...
# 379
# 380  For now, the AI is able to recognize a person ...
# 381  What were their results?BellKor's Pragmatic Ch...
#
#                                                 ISSUES SCORE  \
# 0    Human involvement is still needed to interpret...    8
# 1
# 2                                                         7
# 3    Self driving vehicles or semi-self driving veh...    8
# 4
# ..                                                 ...   ...
# 377                                                       9
# 378  The AI based its calulations and predictions o...    1
# 379
# 380  The biggest technical issue is the lack of pro...    4
# 381  Evident privacy concerns regarding that datase...    7
#
#                                               COMMENTS  \
# 0    Interesting to know that not only laws of phys...
# 1    This article discusses computer vision and mac...
# 2    This field is still being actively researched ...
# 3    The fact that Waymo refused to comment on the ...
# 4    This media article focuses more on the outcome...
# ..                                                 ...
# 377  This report is a useful case study on human in...
# 378  for what seemed like a hopeful and life saving...
# 379
# 380  The article gives not a lot of technical infor...
# 381  The press generally did not explain their algo...
#
#                                             GOAL_clean  \
# 0                     to discover new laws of physics
# 1    identify objects by name and physical appearance
# 2    a new system that is able to automatically dec...
# 3                                   autonomous trucks
# 4    give customers shows that they like but would ...
# ..                                                 ...
# 377  set a base line for ai augmented future in the...
# 378               diagnose and treat and ill patients
# 379
# 380  they are trying to create an ai able to analys...
# 381   improve by at least the accuracy of netflix s...
#
#                                             DATA_clean  \
# 0    observational data of the trajectory of mars a...
# 1
# 2    extracted pairs of linear b scripts words and ...
# 3    data was collected by real world experience dr...
# 4    explicit data given by customers when they lik...
# ..                                                 ...
# 377  to facilitate human ai augmentation organizati...
# 378  symptoms and treatments for a range of illnesses
# 379
# 380  the data used come from the videos already rec...
# 381  data in quadruplet form user movie date of gra...
#
#                                          METHODS_clean  \
# 0                                                  rl
# 1
# 2    character based sequence to sequence seq seq m...
# 3    waymo try improve upon driving visibility of a...
# 4    use machine learning algorithms to place custo...
# ..                                                 ...
# 377  they implemened the cognitive task master mode...
# 378  the system contained knowledge and symptoms of...
# 379
# 380                 not mentioned probably supervised
# 381  bellkor algorithm contains neighborhood based ...
#
#                                          RESULTS_clean  \
# 0    positioned the sun as a center piece of the so...
# 1
# 2    achieved a absolute improvement when applied t...
# 3    waymo declined to awnser on the performance of...
# 4
# ..                                                 ...
# 377
# 378  the project was scrapped following several ser...
# 379
# 380  for now the ai is able to recognize a person o...
# 381  what were their results bellkor s pragmatic ch...
#
#                                           ISSUES_clean  \
# 0    human involvement is still needed to interpret...
# 1
# 2
# 3    self driving vehicles or semi self driving veh...
# 4
# ..                                                 ...
# 377
# 378  the ai based its calulations and predictions o...
# 379
# 380  the biggest technical issue is the lack of pro...
# 381  evident privacy concerns regarding that datase...
#
#                                         COMMENTS_clean
# 0    interesting to know that not only laws of phys...
# 1    this article discusses computer vision and mac...
# 2    this field is still being actively researched ...
# 3    the fact that waymo refused to comment on the ...
# 4    this media article focuses more on the outcome...
# ..                                                 ...
# 377  this report is a useful case study on human in...
# 378  for what seemed like a hopeful and life saving...
# 379
# 380  the article gives not a lot of technical infor...
# 381  the press generally did not explain their algo...
#
# [382 rows x 16 columns]

# %%
# from sklearn.feature_extraction.text import CountVectorizer  
# from sklearn.feature_extraction.text import TfidfTransformer  
# from sklearn.cluster import KMeans

# %%
# #遍历要聚类的列
# cluster_cols=["GOAL_clean","DATA_clean","METHODS_clean","RESULTS_clean","ISSUES_clean","COMMENTS_clean"]
# cluster_num=[3,3,3,3,3,3]
# for i in range(len(cluster_cols)):
#     #将文本中的词语转换为词频矩阵  
#     vectorizer = CountVectorizer()  
#     #计算个词语出现的次数  
#     X = vectorizer.fit_transform(data[cluster_cols[i]])
#     #类调用  
#     transformer = TfidfTransformer()    
#     #将词频矩阵X统计成TF-IDF值  
#     tfidf = transformer.fit_transform(X)  
#     #查看数据结构 tfidf[i][j]表示i类文本中的tf-idf权重  
#     clf = KMeans(n_clusters=cluster_num[i])  
#     s = clf.fit(tfidf.toarray())
#     data[cluster_cols[i]+"_cluster_id"]=clf.labels_

# %%
#去除停用词
data["GOAL_clean"]=data.apply(lambda x:[w for w in x["GOAL_clean"].split(" ") if not w in list_stopWords],axis=1)

# %%
data["DATA_clean"]=data.apply(lambda x:[w for w in x["DATA_clean"].split(" ") if not w in list_stopWords],axis=1)
data["METHODS_clean"]=data.apply(lambda x:[w for w in x["METHODS_clean"].split(" ") if not w in list_stopWords],axis=1)
data["RESULTS_clean"]=data.apply(lambda x:[w for w in x["RESULTS_clean"].split(" ") if not w in list_stopWords],axis=1)
data["ISSUES_clean"]=data.apply(lambda x:[w for w in x["ISSUES_clean"].split(" ") if not w in list_stopWords],axis=1)
data["COMMENTS_clean"]=data.apply(lambda x:[w for w in x["COMMENTS_clean"].split(" ") if not w in list_stopWords],axis=1)

# %%
data
# Out:
#                  file                                             SOURCE  \
# 0    0080846114c8ae51  https://www.nature.com/articles/d41586-019-033...
# 1    00b02003d26e10c9  https://deepmind.com/blog/neural-scene-represe...
# 2    00d25ff5a5d90ac9  https://news.mit.edu/2020/translating-lost-lan...
# 3    011a8060b96d68f5  https://fortune.com/2020/10/13/waymo-autonomou...
# 4    01754bb64df52491  https://www.wired.co.uk/article/how-do-netflix...
# ..                ...                                                ...
# 377  f9b8a5d36032fba5  https://www.cognizant.com/en-uk/artificial-int...
# 378  faa17c0f1217eb56  https://www.theverge.com/2018/7/26/17619382/ib...
# 379  fb975c3aa0f08cee
# 380  fcf271ee3b36865d  https://www.lemonde.fr/les-cles-de-demain/arti...
# 381  ffea5d4bf37fb8d1  > Netflix Awards $1 Million Prize and Starts a...
#
#                                                  AGENT  \
# 0     Swiss Federal Institute of Technology (ETH) i...
# 1             Machines with computer vision equipment
# 2                                                 MIT
# 3                            Waymo (Google Subsidary)
# 4                                              Netflix
# ..                                                 ...
# 377                                         Cognizant
# 378                 IBMâs âWatson for Oncologyâ
# 379
# 380                                               IBM
# 381  Competition Hosted by **Netflix**Algorithm cre...
#
#                                                   GOAL  \
# 0                     To discover new laws of physics
# 1    Identify objects by name and physical appearance
# 2    A new system that is able to automatically dec...
# 3                                   Autonomous trucks
# 4    Give customers shows that they like but would ...
# ..                                                 ...
# 377  Set a base-line for AI-Augmented future in the...
# 378              diagnose and treat and ill patients.
# 379
# 380  They are trying to create an AI able to analys...
# 381  **Improve by at least 10%** the accuracy of Ne...
#
#                                                   DATA  \
# 0    Observational data of the trajectory of Mars a...
# 1
# 2    Extracted pairs of Linear B scripts(words) and...
# 3    Data was collected by real world experience dr...
# 4    Explicit data given by customers when they lik...
# ..                                                 ...
# 377  To facilitate human-AI augmentation, organizat...
# 378  symptoms and treatments for a range of illness...
# 379
# 380  The data used come from the videos already rec...
# 381  Data in quadruplet form: <user, movie, date of...
#
#                                                METHODS  \
# 0                                                  RL
# 1
# 2    character-based sequence-to-sequence (seq2seq)...
# 3    Waymo try improve upon driving visibility of a...
# 4    Use machine learning algorithms to place custo...
# ..                                                 ...
# 377  They implemened the cognitive task master mode...
# 378  the system contained knowledge and symptoms of...
# 379
# 380                Not mentioned, probably supervised
# 381  BellKor Algorithm contains:- Neighborhood-base...
#
#                                                RESULTS  \
# 0    Positioned the Sun as a center-piece of the so...
# 1
# 2    Achieved a 5.5% absolute improvement when appl...
# 3    Waymo declined to awnser on the performance of...
# 4
# ..                                                 ...
# 377
# 378  the project was scrapped following several ser...
# 379
# 380  For now, the AI is able to recognize a person ...
# 381  What were their results?BellKor's Pragmatic Ch...
#
#                                                 ISSUES SCORE  \
# 0    Human involvement is still needed to interpret...    8
# 1
# 2                                                         7
# 3    Self driving vehicles or semi-self driving veh...    8
# 4
# ..                                                 ...   ...
# 377                                                       9
# 378  The AI based its calulations and predictions o...    1
# 379
# 380  The biggest technical issue is the lack of pro...    4
# 381  Evident privacy concerns regarding that datase...    7
#
#                                               COMMENTS  \
# 0    Interesting to know that not only laws of phys...
# 1    This article discusses computer vision and mac...
# 2    This field is still being actively researched ...
# 3    The fact that Waymo refused to comment on the ...
# 4    This media article focuses more on the outcome...
# ..                                                 ...
# 377  This report is a useful case study on human in...
# 378  for what seemed like a hopeful and life saving...
# 379
# 380  The article gives not a lot of technical infor...
# 381  The press generally did not explain their algo...
#
#                                             GOAL_clean  \
# 0                     [discover, new, laws, physics, ]
# 1    [identify, objects, name, physical, appearance, ]
# 2    [new, system, able, automatically, decipher, l...
# 3                               [autonomous, trucks, ]
# 4      [give, customers, shows, like, would, chosen, ]
# ..                                                 ...
# 377  [set, base, line, ai, augmented, future, workf...
# 378                 [diagnose, treat, ill, patients, ]
# 379                                                 []
# 380  [trying, create, ai, able, analyse, real, time...
# 381  [, improve, least, accuracy, netflix, recommen...
#
#                                             DATA_clean  \
# 0    [observational, data, trajectory, mars, sun, s...
# 1                                                   []
# 2    [extracted, pairs, linear, b, scripts, words, ...
# 3    [data, collected, real, world, experience, dri...
# 4    [explicit, data, given, customers, like, disli...
# ..                                                 ...
# 377  [facilitate, human, ai, augmentation, organiza...
# 378         [symptoms, treatments, range, illnesses, ]
# 379                                                 []
# 380  [data, used, come, videos, already, recorded, ...
# 381  [data, quadruplet, form, user, movie, date, gr...
#
#                                          METHODS_clean  \
# 0                                               [rl, ]
# 1                                                   []
# 2    [character, based, sequence, sequence, seq, se...
# 3    [waymo, try, improve, upon, driving, visibilit...
# 4    [use, machine, learning, algorithms, place, cu...
# ..                                                 ...
# 377  [implemened, cognitive, task, master, model, w...
# 378  [system, contained, knowledge, symptoms, every...
# 379                                                 []
# 380                [mentioned, probably, supervised, ]
# 381  [bellkor, algorithm, contains, neighborhood, b...
#
#                                          RESULTS_clean  \
# 0    [positioned, sun, center, piece, solar, system, ]
# 1                                                   []
# 2    [achieved, absolute, improvement, applied, dec...
# 3    [waymo, declined, awnser, performance, self, d...
# 4                                                   []
# ..                                                 ...
# 377                                                 []
# 378  [project, scrapped, following, several, seriou...
# 379                                                 []
# 380  [ai, able, recognize, person, object, distance...
# 381  [results, bellkor, pragmatic, chaos, team, got...
#
#                                           ISSUES_clean  \
# 0    [human, involvement, still, needed, interpret,...
# 1                                                   []
# 2                                                 [, ]
# 3    [self, driving, vehicles, semi, self, driving,...
# 4                                                   []
# ..                                                 ...
# 377                                                 []
# 378  [ai, based, calulations, predictions, hypothet...
# 379                                                 []
# 380  [biggest, technical, issue, lack, processable,...
# 381  [evident, privacy, concerns, regarding, datase...
#
#                                         COMMENTS_clean
# 0    [interesting, know, laws, physics, laws, might...
# 1    [article, discusses, computer, vision, machine...
# 2    [field, still, actively, researched, better, u...
# 3    [fact, waymo, refused, comment, performance, v...
# 4    [media, article, focuses, outcomes, algorithms...
# ..                                                 ...
# 377  [report, useful, case, study, human, interacit...
# 378  [seemed, like, hopeful, life, saving, instrume...
# 379                                                 []
# 380  [article, gives, lot, technical, informations,...
# 381  [press, generally, explain, algorithm, whatsoe...
#
# [382 rows x 16 columns]

# %%
# cluster_id=["GOAL_clean_cluster_id","DATA_clean_cluster_id","METHODS_clean_cluster_id","RESULTS_clean_cluster_id","ISSUES_clean_cluster_id","COMMENTS_clean_cluster_id"]

# %%
# for col in cluster_id:
#     print(data.groupby(col,as_index=False)["file"].count())

# %%
#保存主题词结果
column=[]
cluster=[]
term=[]
prob=[]

# %%
#遍历要聚类的列
cluster_cols=["GOAL_clean","DATA_clean","METHODS_clean","RESULTS_clean","ISSUES_clean","COMMENTS_clean"]
cluster_num=[3,3,3,3,3,3]
topic_num=[10,10,10,10,10,10]
for i in range(len(cluster_cols)):
    dictionary = corpora.Dictionary(data[cluster_cols[i]].values)
    # 计算文本向量
    corpus = [dictionary.doc2bow(text) for text in data[cluster_cols[i]].values]  # 每个text对应的稀疏向量
    # 计算文档TF-IDF
    corpus_tfidf = models.TfidfModel(corpus)[corpus]
    num_topics = cluster_num[i]  # 定义主题数
    lda = models.LdaModel(corpus_tfidf, num_topics=num_topics, id2word=dictionary,
                          alpha=0.01, eta=0.01, minimum_probability=0.001,
                          update_every=1, chunksize=100, passes=1)
    doc_topic = [a for a in lda[corpus_tfidf]]
    id=[]
    for d in doc_topic:
        id.append(np.argmax([i[1] for i in d]))
    data[cluster_cols[i]+"_cluster_id"]=id
    
    num_show_term = topic_num[i]  # 每个主题显示几个词
    print(cluster_cols[i])
    for topic_id in range(num_topics):
        print('主题#%d：\t' % topic_id)
        column.append(cluster_cols[i])
        cluster.append(topic_id)
        term_distribute_all = lda.get_topic_terms(topicid=topic_id)  # 所有词的词分布
        term_distribute = term_distribute_all[:num_show_term]  # 只显示前几个词
        term_distribute = np.array(term_distribute)
        term_id = term_distribute[:, 0].astype(np.int)
        print('词：', end="")
        words=""
        for t in term_id:
            words=words+dictionary.id2token[t]+" "
            print(dictionary.id2token[t], end=' ')
        term.append(words)
        print('概率：', end="")
        print(term_distribute[:, 1])
        prob.append(term_distribute[:, 1])
# Out:
# GOAL_clean
# 主题#0：
# 词：able find could languages early eye people predict google team 概率：[0.0195451  0.01782084 0.01688707 0.01522363 0.01520075 0.01487742
#  0.01448207 0.01442411 0.01388436 0.01369806]
# 主题#1：
# 词： go improve data performance reduce champion time models neural 概率：[0.12144899 0.02680043 0.02447087 0.02100277 0.01754355 0.01745412
#  0.0157333  0.015422   0.01463644 0.01401222]
# 主题#2：
# 词：create ai using system covid learning images machine beat world 概率：[0.02081462 0.01917487 0.01789624 0.01644056 0.015522   0.01537923
#  0.01475927 0.0132771  0.01254368 0.0117386 ]
# DATA_clean
# 主题#0：
# 词：game zinc games eye data google molecules thousands feedback million 概率：[0.02745574 0.02007737 0.01644294 0.0163355  0.01560493 0.01445358
#  0.0139867  0.01361239 0.0126672  0.01224038]
# 主题#1：
# 词： various data past different collected user specified go input 概率：[0.12087578 0.03120935 0.02110724 0.0172462  0.01706805 0.01542426
#  0.01534852 0.01484129 0.01477782 0.01406579]
# 主题#2：
# 词：images database data taken dataset used people patients million face 概率：[0.02563139 0.02134285 0.01829549 0.01566147 0.01537144 0.01428272
#  0.01392651 0.01243974 0.01222942 0.0116057 ]
# METHODS_clean
# 主题#0：
# 词：machine language learning processing natural used facial network using neural 概率：[0.0311638  0.02010823 0.01937025 0.01896821 0.01842762 0.01665721
#  0.01491757 0.01401196 0.01270241 0.01225572]
# 主题#1：
# 词：supervised learning deep network neural models algorithm model classification data 概率：[0.08141615 0.0341083  0.0322133  0.02521339 0.02142452 0.02001985
#  0.01810364 0.017331   0.01485367 0.01484315]
# 主题#2：
# 词： unsupervised learning supervised artificial reinforcement networks recognition convolutional process 概率：[0.09122757 0.04844561 0.02469061 0.01844809 0.0183956  0.01516303
#  0.01321864 0.01220735 0.01220374 0.0119698 ]
# RESULTS_clean
# 主题#0：
# 词：language however improvement faster overall molecules improved network one training 概率：[0.02716915 0.0230659  0.02120874 0.02014142 0.01679378 0.01667573
#  0.01557739 0.01469862 0.01452186 0.01317896]
# 主题#1：
# 词：accuracy identified go patients tests capable first alphago positive less 概率：[0.0181189  0.01693399 0.01546388 0.0153717  0.01519835 0.01501618
#  0.01460784 0.01447628 0.01374024 0.01311429]
# 主题#2：
# 词：accuracy results ai system percent new better model human could 概率：[0.02216688 0.0210745  0.01970767 0.01914274 0.0190643  0.01847831
#  0.01520976 0.01229564 0.01178677 0.01100907]
# ISSUES_clean
# 主题#0：
# 词：data model n could issue images time algorithm also one 概率：[0.0219003  0.020267   0.01969198 0.01862615 0.01535255 0.01365249
#  0.01363884 0.01338519 0.01271439 0.01255275]
# 主题#1：
# 词：person public question issues ethical different technical user research perhaps 概率：[0.02780825 0.01995422 0.01645667 0.01627316 0.01467557 0.01337135
#  0.01328856 0.01326527 0.01276885 0.01251079]
# 主题#2：
# 词：issues people use problems real covid dataset found see testing 概率：[0.09198143 0.02675388 0.02450132 0.02065667 0.01724953 0.01687041
#  0.0168549  0.01680325 0.01565433 0.01540856]
# COMMENTS_clean
# 主题#0：
# 词：help system google cool people specific area could however quite 概率：[0.01028574 0.01022027 0.00983189 0.00913745 0.00837915 0.00779992
#  0.00772203 0.00771901 0.00755439 0.00752177]
# 主题#1：
# 词：n new interesting data many technology like useful human ai 概率：[0.01926564 0.01249535 0.01131395 0.01033483 0.0102048  0.00970789
#  0.00968408 0.00951671 0.00918175 0.00911258]
# 主题#2：
# 词： learning one field comments machine languages public neural company 概率：[0.1549498  0.01337976 0.01258217 0.01239784 0.01165041 0.01031956
#  0.00989826 0.00943071 0.00897044 0.00846269]

# %%
data
# Out:
#                  file                                             SOURCE  \
# 0    0080846114c8ae51  https://www.nature.com/articles/d41586-019-033...
# 1    00b02003d26e10c9  https://deepmind.com/blog/neural-scene-represe...
# 2    00d25ff5a5d90ac9  https://news.mit.edu/2020/translating-lost-lan...
# 3    011a8060b96d68f5  https://fortune.com/2020/10/13/waymo-autonomou...
# 4    01754bb64df52491  https://www.wired.co.uk/article/how-do-netflix...
# ..                ...                                                ...
# 377  f9b8a5d36032fba5  https://www.cognizant.com/en-uk/artificial-int...
# 378  faa17c0f1217eb56  https://www.theverge.com/2018/7/26/17619382/ib...
# 379  fb975c3aa0f08cee
# 380  fcf271ee3b36865d  https://www.lemonde.fr/les-cles-de-demain/arti...
# 381  ffea5d4bf37fb8d1  > Netflix Awards $1 Million Prize and Starts a...
#
#                                                  AGENT  \
# 0     Swiss Federal Institute of Technology (ETH) i...
# 1             Machines with computer vision equipment
# 2                                                 MIT
# 3                            Waymo (Google Subsidary)
# 4                                              Netflix
# ..                                                 ...
# 377                                         Cognizant
# 378                 IBMâs âWatson for Oncologyâ
# 379
# 380                                               IBM
# 381  Competition Hosted by **Netflix**Algorithm cre...
#
#                                                   GOAL  \
# 0                     To discover new laws of physics
# 1    Identify objects by name and physical appearance
# 2    A new system that is able to automatically dec...
# 3                                   Autonomous trucks
# 4    Give customers shows that they like but would ...
# ..                                                 ...
# 377  Set a base-line for AI-Augmented future in the...
# 378              diagnose and treat and ill patients.
# 379
# 380  They are trying to create an AI able to analys...
# 381  **Improve by at least 10%** the accuracy of Ne...
#
#                                                   DATA  \
# 0    Observational data of the trajectory of Mars a...
# 1
# 2    Extracted pairs of Linear B scripts(words) and...
# 3    Data was collected by real world experience dr...
# 4    Explicit data given by customers when they lik...
# ..                                                 ...
# 377  To facilitate human-AI augmentation, organizat...
# 378  symptoms and treatments for a range of illness...
# 379
# 380  The data used come from the videos already rec...
# 381  Data in quadruplet form: <user, movie, date of...
#
#                                                METHODS  \
# 0                                                  RL
# 1
# 2    character-based sequence-to-sequence (seq2seq)...
# 3    Waymo try improve upon driving visibility of a...
# 4    Use machine learning algorithms to place custo...
# ..                                                 ...
# 377  They implemened the cognitive task master mode...
# 378  the system contained knowledge and symptoms of...
# 379
# 380                Not mentioned, probably supervised
# 381  BellKor Algorithm contains:- Neighborhood-base...
#
#                                                RESULTS  \
# 0    Positioned the Sun as a center-piece of the so...
# 1
# 2    Achieved a 5.5% absolute improvement when appl...
# 3    Waymo declined to awnser on the performance of...
# 4
# ..                                                 ...
# 377
# 378  the project was scrapped following several ser...
# 379
# 380  For now, the AI is able to recognize a person ...
# 381  What were their results?BellKor's Pragmatic Ch...
#
#                                                 ISSUES SCORE  \
# 0    Human involvement is still needed to interpret...    8
# 1
# 2                                                         7
# 3    Self driving vehicles or semi-self driving veh...    8
# 4
# ..                                                 ...   ...
# 377                                                       9
# 378  The AI based its calulations and predictions o...    1
# 379
# 380  The biggest technical issue is the lack of pro...    4
# 381  Evident privacy concerns regarding that datase...    7
#
#                                               COMMENTS  ...  \
# 0    Interesting to know that not only laws of phys...  ...
# 1    This article discusses computer vision and mac...  ...
# 2    This field is still being actively researched ...  ...
# 3    The fact that Waymo refused to comment on the ...  ...
# 4    This media article focuses more on the outcome...  ...
# ..                                                 ...  ...
# 377  This report is a useful case study on human in...  ...
# 378  for what seemed like a hopeful and life saving...  ...
# 379                                                     ...
# 380  The article gives not a lot of technical infor...  ...
# 381  The press generally did not explain their algo...  ...
#
#                                          METHODS_clean  \
# 0                                               [rl, ]
# 1                                                   []
# 2    [character, based, sequence, sequence, seq, se...
# 3    [waymo, try, improve, upon, driving, visibilit...
# 4    [use, machine, learning, algorithms, place, cu...
# ..                                                 ...
# 377  [implemened, cognitive, task, master, model, w...
# 378  [system, contained, knowledge, symptoms, every...
# 379                                                 []
# 380                [mentioned, probably, supervised, ]
# 381  [bellkor, algorithm, contains, neighborhood, b...
#
#                                          RESULTS_clean  \
# 0    [positioned, sun, center, piece, solar, system, ]
# 1                                                   []
# 2    [achieved, absolute, improvement, applied, dec...
# 3    [waymo, declined, awnser, performance, self, d...
# 4                                                   []
# ..                                                 ...
# 377                                                 []
# 378  [project, scrapped, following, several, seriou...
# 379                                                 []
# 380  [ai, able, recognize, person, object, distance...
# 381  [results, bellkor, pragmatic, chaos, team, got...
#
#                                           ISSUES_clean  \
# 0    [human, involvement, still, needed, interpret,...
# 1                                                   []
# 2                                                 [, ]
# 3    [self, driving, vehicles, semi, self, driving,...
# 4                                                   []
# ..                                                 ...
# 377                                                 []
# 378  [ai, based, calulations, predictions, hypothet...
# 379                                                 []
# 380  [biggest, technical, issue, lack, processable,...
# 381  [evident, privacy, concerns, regarding, datase...
#
#                                         COMMENTS_clean GOAL_clean_cluster_id  \
# 0    [interesting, know, laws, physics, laws, might...                     0
# 1    [article, discusses, computer, vision, machine...                     1
# 2    [field, still, actively, researched, better, u...                     0
# 3    [fact, waymo, refused, comment, performance, v...                     1
# 4    [media, article, focuses, outcomes, algorithms...                     0
# ..                                                 ...                   ...
# 377  [report, useful, case, study, human, interacit...                     2
# 378  [seemed, like, hopeful, life, saving, instrume...                     2
# 379                                                 []                     1
# 380  [article, gives, lot, technical, informations,...                     0
# 381  [press, generally, explain, algorithm, whatsoe...                     1
#
#     DATA_clean_cluster_id  METHODS_clean_cluster_id  RESULTS_clean_cluster_id  \
# 0                       2                         0                         2
# 1                       1                         2                         0
# 2                       1                         1                         0
# 3                       1                         0                         0
# 4                       2                         0                         0
# ..                    ...                       ...                       ...
# 377                     0                         1                         0
# 378                     0                         2                         2
# 379                     1                         2                         0
# 380                     2                         2                         2
# 381                     1                         1                         2
#
#      ISSUES_clean_cluster_id  COMMENTS_clean_cluster_id
# 0                          1                          2
# 1                          0                          2
# 2                          0                          2
# 3                          1                          2
# 4                          0                          0
# ..                       ...                        ...
# 377                        0                          1
# 378                        2                          1
# 379                        0                          2
# 380                        0                          0
# 381                        1                          1
#
# [382 rows x 22 columns]

# %%
data.to_csv("./result.csv",index=None)

# %%
result2=pd.DataFrame({"字段":column,"主题":cluster,"词":term,"概率":prob})

# %%
result2.to_csv("./result2.csv",index=None)
